# %% [markdown]
# # SUMMER OLYMPICS  DATA ANALYSIS ASSIGNMENT

# %% [markdown]
# ## 1. In how many cities Summer Olympics is held so far?¶

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("summer.csv")

# %%
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# ## 2.Which sport is having most number of Gold Medals so far? (Top 5)

# %%
l=df[df['Medal']=='Gold']
data=[]
for sport in l['Sport'].unique():
    data.append([sport, len(l[l['Sport']==sport])])
pd.DataFrame(data,columns = ['Sport','Medals']).sort_values(by='Medals', ascending=False).head().plot(x = 'Sport', y = 'Medals', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# ## 3. Which sport is having most number of medals so far? (Top 5)

# %%
data=[]
for sport in df['Sport'].unique():
    data.append([sport, len(df[df['Sport']==sport])])
pd.DataFrame(data,columns = ['Sport','Medals']).sort_values(by='Medals', ascending=False).head().plot(x = 'Sport', y = 'Medals', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %% [markdown]
# ## 4. Which player has won most number of medals? (Top 5)

# %%
data=[]

for athlete in df['Athlete'].unique():
    data.append([athlete, len(df[df['Athlete']==athlete])])    
pd.DataFrame(data,columns = ['Athlete','Medals']).sort_values(by='Medals', ascending=False).head().plot(x = 'Athlete', y = 'Medals', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ## 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
l = df[df['Medal']=='Gold']
data=[]
for Athlete in l['Athlete'].unique():
    data.append([Athlete, len(l[l['Athlete']==Athlete])])
pd.DataFrame(data,columns = ['Athlete','Medals']).sort_values(by='Medals', ascending=False).head().plot(x = 'Athlete', y = 'Medals', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ## 6. In which year India won first Gold Medal in Summer Olympics?

# %%
l=df[df['Medal']=='Gold']
b=l[l['Country']=='IND']
data=[]
for Year in b['Year'].unique():
    print(Year)
    break
# Out:
# 1928

# %% [markdown]
# ## 7. Which event is most popular in terms on number of players? (Top 5)

# %%
data=[]
for Event in df['Event'].unique():
    data.append([Event, len(df[df['Event']==Event])])    
pd.DataFrame(data,columns = ['Event','Athlete']).sort_values(by='Athlete', ascending=False).head().plot(x = 'Event', y = 'Athlete', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Event'>

# %% [markdown]
# ## 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
l=df[df['Medal']=='Gold']
c=l[l['Gender']=='Women']
data=[]
for Sport in c['Sport'].unique():
    data.append([Sport, len(c[c['Sport']==Sport])]) 
#print(data)
pd.DataFrame(data,columns = ['Sport','Medal']).sort_values(by='Medal', ascending=False).head().plot(x = 'Sport', y = 'Medal', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Sport'>
